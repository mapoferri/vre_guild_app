# %%
import requests

# %%
import argparse
import pandas as pd
import requests

parser=argparse.ArgumentParser(description='create the folder datasets and download all the required data')



def retrieve_gda(source):
    auth_params = {"email":"francesco.gualdi@live.com","password":"nidodelcuculo0"}
    api_host='https://www.disgenet.org/api'
    req=requests.Session()
    url = api_host+'/auth/'
    response = req.post(url, data=auth_params)
    token=response.json()['token']
    req.headers.update({"Authorization": "Bearer %s" % token}) 
    return req.get(api_host+'/gda/source/{}'.format(source)).json()


# def retrieve_hippie():
#     requests.get=

# %%
gdas=retrieve_gda('CURATED')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\miniconda3\envs\Network_visualization\lib\site-packages\requests\models.py:910, in Response.json(self, **kwargs)
#     909 try:
# --> 910     return complexjson.loads(self.text, **kwargs)
#     911 except JSONDecodeError as e:
#     912     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     913     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\miniconda3\envs\Network_visualization\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\miniconda3\envs\Network_visualization\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\miniconda3\envs\Network_visualization\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 gdas=retrieve_gda('CURATED')
#
# Input In [15], in retrieve_gda(source)
#      12 token=response.json()['token']
#      13 req.headers.update({"Authorization": "Bearer %s" % token})
# ---> 14 return req.get(api_host+'/gda/source/{}'.format(source)).json()
#
# File ~\miniconda3\envs\Network_visualization\lib\site-packages\requests\models.py:917, in Response.json(self, **kwargs)
#     915     raise RequestsJSONDecodeError(e.message)
#     916 else:
# --> 917     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: [Errno Expecting value] <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>504 Gateway Timeout</title>
# </head><body>
# <h1>Gateway Timeout</h1>
# <p>The gateway did not receive a timely response
# from the upstream server or application.</p>
# </body></html>
# : 0

# %%
gdas

# %%
ncur=pd.read_csv('../datasets/all_gda.tsv',sep='\t')
cur=pd.read_csv('../datasets/curated_gda.tsv',sep='\t')

# %%
ncur
# Out:
#             geneId geneSymbol    DSI    DPI diseaseId  \
# 0                1       A1BG  0.700  0.538  C0001418
# 1                1       A1BG  0.700  0.538  C0002736
# 2                1       A1BG  0.700  0.538  C0003578
# 3                1       A1BG  0.700  0.538  C0003864
# 4                1       A1BG  0.700  0.538  C0008373
# ...            ...        ...    ...    ...       ...
# 1134937  115804232     CEROX1    NaN    NaN  C0005890
# 1134938  115891964   MIR223HG  0.861  0.077  C0023418
# 1134939  115891964   MIR223HG  0.861  0.077  C0023467
# 1134940  115891964   MIR223HG  0.861  0.077  C0598766
# 1134941  115891964   MIR223HG  0.861  0.077  C1332977
#
#                            diseaseName diseaseType diseaseClass  \
# 0                       Adenocarcinoma       group          C04
# 1        Amyotrophic Lateral Sclerosis     disease      C18;C10
# 2                                Apnea   phenotype      C23;C08
# 3                            Arthritis     disease          C05
# 4                        Cholesteatoma     disease          C17
# ...                                ...         ...          ...
# 1134937                    Body Height   phenotype          NaN
# 1134938                       leukemia     disease          C04
# 1134939    Leukemia, Myelocytic, Acute     disease          C04
# 1134940                 Leukemogenesis     disease      C23;C04
# 1134941             Childhood Leukemia     disease          C04
#
#          diseaseSemanticType  score   EI  YearInitial  YearFinal  NofPmids  \
# 0         Neoplastic Process   0.01  1.0       2008.0     2008.0         1
# 1        Disease or Syndrome   0.01  1.0       2008.0     2008.0         1
# 2            Sign or Symptom   0.01  1.0       2017.0     2017.0         1
# 3        Disease or Syndrome   0.01  1.0       2019.0     2019.0         1
# 4        Disease or Syndrome   0.01  1.0       2020.0     2020.0         1
# ...                      ...    ...  ...          ...        ...       ...
# 1134937   Organism Attribute   0.10  1.0       2019.0     2019.0         1
# 1134938   Neoplastic Process   0.01  1.0       2016.0     2016.0         1
# 1134939   Neoplastic Process   0.01  1.0       2016.0     2016.0         1
# 1134940   Neoplastic Process   0.01  1.0       2016.0     2016.0         1
# 1134941   Neoplastic Process   0.01  1.0       2016.0     2016.0         1
#
#          NofSnps   source
# 0              0    LHGDN
# 1              0   BEFREE
# 2              0   BEFREE
# 3              0   BEFREE
# 4              0   BEFREE
# ...          ...      ...
# 1134937        0  GWASCAT
# 1134938        0   BEFREE
# 1134939        0   BEFREE
# 1134940        0   BEFREE
# 1134941        0   BEFREE
#
# [1134942 rows x 16 columns]

# %%
cur.columns
# Out:
# Index(['geneId', 'geneSymbol', 'DSI', 'DPI', 'diseaseId', 'diseaseName',
#        'diseaseType', 'diseaseClass', 'diseaseSemanticType', 'score', 'EI',
#        'YearInitial', 'YearFinal', 'NofPmids', 'NofSnps', 'source'],
#       dtype='object')

# %%
ncur.columns=['geneSymbol','geneId',]
# Out:
#        Gene  Gene_id                       Gene_Full_Name  DSI_g  DPI_g  \
# 0      A1BG        1               alpha-1-B glycoprotein  0.700  0.538
# 1      A1BG        1               alpha-1-B glycoprotein  0.700  0.538
# 2      NAT2       10                N-acetyltransferase 2  0.451  0.885
# 3      NAT2       10                N-acetyltransferase 2  0.451  0.885
# 4      NAT2       10                N-acetyltransferase 2  0.451  0.885
# ...     ...      ...                                  ...    ...    ...
# 84033  SCO2     9997  synthesis of cytochrome C oxidase 2  0.479  0.846
# 84034  SCO2     9997  synthesis of cytochrome C oxidase 2  0.479  0.846
# 84035  SCO2     9997  synthesis of cytochrome C oxidase 2  0.479  0.846
# 84036  SCO2     9997  synthesis of cytochrome C oxidase 2  0.479  0.846
# 84037  SCO2     9997  synthesis of cytochrome C oxidase 2  0.479  0.846
#
#                 pLI                                            Disease  \
# 0      4.991700e-09                                       Hepatomegaly
# 1      4.991700e-09                                      Schizophrenia
# 2      3.274400e-06              Malignant neoplasm of urinary bladder
# 3      3.274400e-06                                   Bladder Neoplasm
# 4      3.274400e-06                       Malignant neoplasm of breast
# ...             ...                                                ...
# 84033  7.547300e-07  Leigh Syndrome due to Mitochondrial Complex V ...
# 84034  7.547300e-07  Cardioencephalomyopathy, Fatal Infantile, due ...
# 84035  7.547300e-07                          Myopia, susceptibility to
# 84036  7.547300e-07  Necrotizing encephalopathy, infantile subacute...
# 84037  7.547300e-07            Hypertrophic obstructive cardiomyopathy
#
#       Disease_id       Type  Score_gda      EL_gda  EI_gda  N_PMIDs  \
# 0       C0019209  phenotype        0.3         NaN   1.000        1
# 1       C0036341    disease        0.3         NaN   1.000        1
# 2       C0005684    disease        0.4         NaN   0.939        5
# 3       C0005695    disease        0.4         NaN   0.935        5
# 4       C0006142    disease        0.4         NaN   0.857        1
# ...          ...        ...        ...         ...     ...      ...
# 84033   C1850600    disease        0.3  definitive   1.000        7
# 84034   C1858424    disease        0.7         NaN   1.000       13
# 84035   C2931111    disease        0.3         NaN     NaN        0
# 84036   C2931891    disease        0.3  definitive   1.000        7
# 84037   C4551472    disease        0.4         NaN   0.909        2
#
#        N_SNPs_gda  First_Ref  Last_Ref
# 0               0     2017.0    2017.0
# 1               0     2015.0    2015.0
# 2               0     1995.0    2018.0
# 3               0     1995.0    2018.0
# 4               0     1996.0    2018.0
# ...           ...        ...       ...
# 84033           0     1999.0    2010.0
# 84034           8     1999.0    2016.0
# 84035           0        NaN       NaN
# 84036           0     1999.0    2010.0
# 84037           0     2000.0    2018.0
#
# [84038 rows x 16 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
def CreateNodes(GdaDataset,curated=True,GdaScore=0.03,mode='norm_dis'):
    ppi_network_edges=pd.read_csv('inputs/hippie_interactome.sif',sep=' ')
    ppi_network_edges.columns=['source','score','target']
    
    if curated:
        GeneColumn='Gene_id'
        ScoreColumn='Score_gda'
    else:
        GeneColumn='geneId'
        ScoreColumn='score'
    
    GdaDataset=GdaDataset[GdaDataset[ScoreColumn]>=GdaScore]
    seeds=GdaDataset[[GeneColumn, ScoreColumn]]
    seeds=seeds[(seeds[GeneColumn].isin(ppi_network_edges.source) | (seeds[GeneColumn].isin(ppi_network_edges.target)))]
    nodes=pd.DataFrame(set(ppi_network_edges.source.tolist() + ppi_network_edges.target.tolist()),columns=[GeneColumn])
    nodes_wo_seeds=pd.DataFrame([node for node in nodes[GeneColumn].tolist() if node not in seeds[GeneColumn].tolist()],columns=[GeneColumn])
    nodes_wo_seeds[ScoreColumn]=0
    if mode=='dis':
        nodes=pd.concat([seeds,nodes_wo_seeds])
        nodes.to_csv('../inputs/nodes.sif', sep=' ', index=False, header=False)
    elif mode=='norm_dis':
        nodes=pd.concat([seeds,nodes_wo_seeds])
        ScoreMax=nodes[ScoreColumn].max()
        ScoreMin=nodes[ScoreColumn].min()
        nodes[ScoreColumn]=nodes[ScoreColumn].apply(lambda x: (x-ScoreMin)/(ScoreMax-ScoreMin))
        return nodes
    elif mode == 'binary':
        nodes=pd.concat([seeds,nodes_wo_seeds])
        nodes[ScoreColumn]=[1 if score > 0 else 0 for score in nodes[ScoreColumn].tolist()]
        print(nodes)
        return nodes

# %%
df=pd.read_csv('../datasets/all_gda.tsv',sep='\t')

# %%
df
# Out:
#             geneId geneSymbol    DSI    DPI diseaseId  \
# 0                1       A1BG  0.700  0.538  C0001418
# 1                1       A1BG  0.700  0.538  C0002736
# 2                1       A1BG  0.700  0.538  C0003578
# 3                1       A1BG  0.700  0.538  C0003864
# 4                1       A1BG  0.700  0.538  C0008373
# ...            ...        ...    ...    ...       ...
# 1134937  115804232     CEROX1    NaN    NaN  C0005890
# 1134938  115891964   MIR223HG  0.861  0.077  C0023418
# 1134939  115891964   MIR223HG  0.861  0.077  C0023467
# 1134940  115891964   MIR223HG  0.861  0.077  C0598766
# 1134941  115891964   MIR223HG  0.861  0.077  C1332977
#
#                            diseaseName diseaseType diseaseClass  \
# 0                       Adenocarcinoma       group          C04
# 1        Amyotrophic Lateral Sclerosis     disease      C18;C10
# 2                                Apnea   phenotype      C23;C08
# 3                            Arthritis     disease          C05
# 4                        Cholesteatoma     disease          C17
# ...                                ...         ...          ...
# 1134937                    Body Height   phenotype          NaN
# 1134938                       leukemia     disease          C04
# 1134939    Leukemia, Myelocytic, Acute     disease          C04
# 1134940                 Leukemogenesis     disease      C23;C04
# 1134941             Childhood Leukemia     disease          C04
#
#          diseaseSemanticType  score   EI  YearInitial  YearFinal  NofPmids  \
# 0         Neoplastic Process   0.01  1.0       2008.0     2008.0         1
# 1        Disease or Syndrome   0.01  1.0       2008.0     2008.0         1
# 2            Sign or Symptom   0.01  1.0       2017.0     2017.0         1
# 3        Disease or Syndrome   0.01  1.0       2019.0     2019.0         1
# 4        Disease or Syndrome   0.01  1.0       2020.0     2020.0         1
# ...                      ...    ...  ...          ...        ...       ...
# 1134937   Organism Attribute   0.10  1.0       2019.0     2019.0         1
# 1134938   Neoplastic Process   0.01  1.0       2016.0     2016.0         1
# 1134939   Neoplastic Process   0.01  1.0       2016.0     2016.0         1
# 1134940   Neoplastic Process   0.01  1.0       2016.0     2016.0         1
# 1134941   Neoplastic Process   0.01  1.0       2016.0     2016.0         1
#
#          NofSnps   source
# 0              0    LHGDN
# 1              0   BEFREE
# 2              0   BEFREE
# 3              0   BEFREE
# 4              0   BEFREE
# ...          ...      ...
# 1134937        0  GWASCAT
# 1134938        0   BEFREE
# 1134939        0   BEFREE
# 1134940        0   BEFREE
# 1134941        0   BEFREE
#
# [1134942 rows x 16 columns]

# %%
df=df[df.diseaseName.str.contains('Intervertebral Disc Degeneration')]

# %%
df.score.max()
# Out:
# 0.36

# %%
nod=CreateNodes(df,GdaScore=0.03,curated=False)

# %%
df[df.score>0.03].shape
# Out:
# (44, 16)

# %%
nod.score.sort_values()
# Out:
# 7856      0.000000
# 10488     0.000000
# 10489     0.000000
# 10490     0.000000
# 10491     0.000000
#             ...
# 365650    0.305556
# 373313    0.333333
# 501119    0.916667
# 578980    0.916667
# 608298    1.000000
# Name: score, Length: 15839, dtype: float64

# %%
nod
